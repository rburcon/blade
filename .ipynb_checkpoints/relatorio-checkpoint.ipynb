# %% [markdown]
# # Ventoinha para ventilação de dispositivos eletrônicos - simulação

# %% [markdown]
# Dados do dispositivo:
# * Velocidade = 954.92 RPM

# %% [markdown]
# ![image.png](attachment:fd09dcdb-5136-40f9-9fb2-8b409f0d1ecf.png)

# %% [markdown]
# ## Pressão relativa e linhas de corrente

# %% [markdown]
# ![image.png](attachment:d8d0c11a-2ee1-4fae-a05c-aa0a612987a2.png)

# %% [markdown]
# ## Velocidade do escoamento

# %% [markdown]
# Considerando superfície coincidente com o plano YZ

# %% [markdown]
# ![image.png](attachment:04710ce9-5729-41c3-8fe3-006f5a7b061b.png)

# %% [markdown]
# Consirerando linhas de fluxo por todo o volume de controle

# %% [markdown]
# ![image.png](attachment:5eb63157-59f6-49ca-b370-01f03c832e31.png)

# %% [markdown]
# ## Torque ocorrido no rotor devido ao fluxo

# %% [markdown]
# O torque no eixo de acionamento é o que ocorre no eixo Z

# %% [markdown]
# ![momento.png](attachment:728a63d2-282e-4d4d-98eb-0ad1e20eb771.png)

# %% [markdown]
# ## Fluxo de ar calculado na saída

# %% [markdown]
# O fluxo é a integral da velocidade no eixo Z na superfície de saída

# %% [markdown]
# ![flow_outlet.png](attachment:f5479ad6-adac-4003-a1dc-9a0530f65ea2.png)

# %% [markdown]
# O fuxo de ar na saída é de  0.000477541m³/s
